# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# data => https://www.kaggle.com/datasets/shivam2503/diamonds

# %%
df = pd.read_csv("diamonds.csv")

# %%
df
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53940 non-null  int64
#  1   carat       53940 non-null  float64
#  2   cut         53940 non-null  object
#  3   color       53940 non-null  object
#  4   clarity     53940 non-null  object
#  5   depth       53940 non-null  float64
#  6   table       53940 non-null  float64
#  7   price       53940 non-null  int64
#  8   x           53940 non-null  float64
#  9   y           53940 non-null  float64
#  10  z           53940 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.5+ MB

# %%
df.drop(columns="Unnamed: 0", axis=1, inplace=True)

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
sns.heatmap(data=df.corr(numeric_only=True), cmap="inferno", annot=True)
plt.show()

# %%
sns.boxplot(x="clarity",y="price", data=df)
plt.show()

# %%
df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
df.drop(df[df["z"]==0].index, inplace=True)
df.drop(df[df["x"]==0].index, inplace=True)
df.drop(df[df["y"]==0].index, inplace=True)

# %%
df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53920.000000  53920.000000  53920.000000  53920.000000  53920.000000
# mean       0.797698     61.749514     57.456834   3930.993231      5.731627
# std        0.473795      1.432331      2.234064   3987.280446      1.119423
# min        0.200000     43.000000     43.000000    326.000000      3.730000
# 25%        0.400000     61.000000     56.000000    949.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5323.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53920.000000  53920.000000
# mean       5.734887      3.540046
# std        1.140126      0.702530
# min        3.680000      1.070000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
#outliers

# %%
sns.scatterplot(x="table", y="price", data=df)
plt.show()

# %%
len(df[(df["table"]<75) & (df["table"]>40)])
# Out:
# 53917

# %%
sns.scatterplot(x="depth", y="price", data=df)
plt.show()

# %%
len(df[(df["depth"]<75) & (df["depth"]>50)])
# Out:
# 53914

# %%
sns.scatterplot(x="z", y="price", data=df)
plt.show()

# %%
len(df[(df["z"]<30) & (df["z"]>2)])
# Out:
# 53916

# %%
sns.scatterplot(x="y", y="price", data=df)
plt.show()

# %%
len(df[(df["y"]<30)])
# Out:
# 53918

# %%
df = df[(df["y"]<30)]
df = df[(df["z"]<30) & (df["z"]>2)]
df = df[(df["depth"]<75) & (df["depth"]>50)]
df = df[(df["table"]<75) & (df["table"]>40)]

# %%
df.shape
# Out:
# (53905, 10)

# %%
df.tail()
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64

# %%
#encoding and scaling

# %%
df["cut"].value_counts()
# Out:
# cut
# Ideal        21543
# Premium      13779
# Very Good    12080
# Good          4902
# Fair          1601
# Name: count, dtype: int64

# %%
df["color"].value_counts()
# Out:
# color
# G    11281
# E     9792
# F     9535
# H     8296
# D     6774
# I     5420
# J     2807
# Name: count, dtype: int64

# %%
df["clarity"].value_counts()
# Out:
# clarity
# SI1     13058
# VS2     12250
# SI2      9183
# VS1      8167
# VVS2     5066
# VVS1     3654
# IF       1790
# I1        737
# Name: count, dtype: int64

# %%
X = df.drop(columns="price", axis=1)
y = df["price"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y, train_size = 0.25, random_state=15)

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
label_encoder = LabelEncoder()

# %%
for col in ["cut","color","clarity"]:
    X_train[col] = label_encoder.fit_transform(X_train[col])
    X_test[col] = label_encoder.transform(X_test[col])

# %%
X_train.head()
# Out:
#        carat  cut  color  clarity  depth  table     x     y     z
# 11731   1.00    1      3        5   62.7   58.0  6.24  6.33  3.94
# 4860    1.00    3      5        3   61.6   59.0  6.34  6.41  3.93
# 51307   0.31    4      3        5   59.0   60.0  4.37  4.41  2.59
# 11677   1.12    3      5        4   62.2   59.0  6.66  6.59  4.12
# 14860   1.14    3      4        5   60.2   58.0  6.74  6.81  4.08

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
reg = LinearRegression()

# %%
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(X_test)

# %%
r2_score(y_pred,y_test)
# Out:
# 0.8713509489726394

# %%
print("mae: ",mean_absolute_error(y_test,y_pred))
print("r2-score: ",r2_score(y_test,y_pred))
print("mse:", mean_squared_error(y_test,y_pred))
# Out:
# mae:  850.6029677258315
# r2-score:  0.8857689385202218
# mse: 1821941.0003462883

# %%
print("mae: ",mean_absolute_error(y_test,y_pred))
print("r2-score: ",r2_score(y_test,y_pred))
print("mse:", mean_squared_error(y_test,y_pred))
plt.scatter(y_test,y_pred, color="pink")
plt.title("Linear Regression")
plt.show()
# Out:
# mae:  850.6029677258315
# r2-score:  0.8857689385202218
# mse: 1821941.0003462883

# %%
# Linear Regression / R2 Score = 0.88

# %%
from sklearn.svm import SVR

# %%
svr = SVR()
svr.fit(X_train,y_train)
y_pred = svr.predict(X_test)
print("mae: ",mean_absolute_error(y_test,y_pred))
print("r2-score: ",r2_score(y_test,y_pred))
print("mse:", mean_squared_error(y_test,y_pred))
plt.scatter(y_test,y_pred, color="purple")
plt.title("Support Vector Regression (Base Parameters)")
plt.show()
# Out:
# mae:  1813.4109779700104
# r2-score:  0.26264493807524936
# mse: 11760526.442900982

# %%
# SVR
# R2 Score = 0.26
# MAE = 1813
# MSE = 11760526

# %%
#hyperparameter

# %%
from sklearn.model_selection import GridSearchCV,StratifiedKFold

# %%
cv = StratifiedKFold()

# %%
params = {
    "C" : [1,10,100,1000],
    "kernel" : ["rbf","linear"],
    "gamma" : [0.01,0.1,1]
}

# %%
grid = GridSearchCV(estimator=SVR(), param_grid=params, refit=True)

# %%
grid
# Out:
# GridSearchCV(estimator=SVR(),
#              param_grid={'C': [1, 10, 100, 1000], 'gamma': [0.01, 0.1, 1],
#                          'kernel': ['rbf', 'linear']})

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
grid.fit(X_train,y_train)
y_pred = grid.predict(X_test)
print("mae: ",mean_absolute_error(y_test,y_pred))
print("r2-score: ",r2_score(y_test,y_pred))
print("mse:", mean_squared_error(y_test,y_pred))
plt.scatter(y_test,y_pred)
plt.title("Grid Search Cross Validation with SVR")
plt.show()
# Out:
# mae:  500.0795344090954
# r2-score:  0.9378191665345635
# mse: 991760.1084923687

# %%
# Grid Search Croos Validation with SVR
# R2 Score = 0.93
# MAE = 500
# MSE = 991760

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
tree = DecisionTreeRegressor()

# %%
tree.fit(X_train,y_train)
y_pred = tree.predict(X_test)
print("mae: ",mean_absolute_error(y_test,y_pred))
print("r2-score: ",r2_score(y_test,y_pred))
print("mse:", mean_squared_error(y_test,y_pred))
plt.scatter(y_test,y_pred, color= "green")
plt.title("Decision Tree Regression")
plt.show()
# Out:
# mae:  405.18249276509437
# r2-score:  0.9584282742573418
# mse: 663052.8562418066

# %%
# Decision Tree Regressor
# R2 Score = 0.95
# MAE = 405
# MSE = 669006

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knn = KNeighborsRegressor(n_neighbors=5)

# %%
knn.fit(X_train,y_train)
y_pred = knn.predict(X_test)
print("mae: ",mean_absolute_error(y_test,y_pred))
print("r2-score: ",r2_score(y_test,y_pred))
print("mse:", mean_squared_error(y_test,y_pred))
plt.scatter(y_test,y_pred, color= "orange")
plt.title("K Nearest Neighbors Regression")
plt.show()
# Out:
# mae:  481.53773281555317
# r2-score:  0.9442819271847028
# mse: 888681.5898181996

# %%
# KNN Regression 
# R2 Score = 0.94
# MAE = 481
# MSE = 888681

# %%
import xgboost as xgb

# %%
xgb_model = xgb.XGBRegressor(objective='reg:squarederror', n_estimators=100, learning_rate=0.1, max_depth=5, random_state=42)
xgb_model.fit(X_train, y_train)
y_pred = xgb_model.predict(X_test)
print("mae: ",mean_absolute_error(y_test,y_pred))
print("r2-score: ",r2_score(y_test,y_pred))
print("mse:", mean_squared_error(y_test,y_pred))
plt.scatter(y_test,y_pred, color= "red")
plt.title("XGBoost")
plt.show()
# Out:
# mae:  301.42071533203125
# r2-score:  0.979367733001709
# mse: 329077.0625

# %%
# XGBoost
# R2 Score = 0.9793
# MAE = 301.42
# MSE = 329077.06

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)
print("mae: ",mean_absolute_error(y_test,y_pred))
print("r2-score: ",r2_score(y_test,y_pred))
print("mse:", mean_squared_error(y_test,y_pred))
plt.scatter(y_test,y_pred, color= "black")
plt.title("Random Forest Regressor")
plt.show()
# Out:
# mae:  297.79091249444934
# r2-score:  0.9781026775844999
# mse: 349253.77554741513

# %%
# Random Forest Regressor
# R2 Score = 0.9781
# MAE = 297.79
# MSE = 349253.77

# %%
data = {
    "Model": ["Linear Regression", "SVR (Base)", "SVR (Grid)", "Decision Tree", "KNN","XGBoost","Random Forest"],
    "MAE": [850.60, 1813.41, 500.08, 405.15, 481.54,301.42, 297.79],
    "MSE": [1821941.0, 11760526.4, 991760.1, 669006.9, 888681.6, 329077.0625, 349253.77],
    "R2 Score": [0.8858, 0.2626, 0.9378, 0.9580, 0.9442, 0.9793, 0.9781]
}

df_compare = pd.DataFrame(data)

print(df_compare)
# Out:
#                Model      MAE           MSE  R2 Score
# 0  Linear Regression   850.60  1.821941e+06    0.8858
# 1         SVR (Base)  1813.41  1.176053e+07    0.2626
# 2         SVR (Grid)   500.08  9.917601e+05    0.9378
# 3      Decision Tree   405.15  6.690069e+05    0.9580
# 4                KNN   481.54  8.886816e+05    0.9442
# 5            XGBoost   301.42  3.290771e+05    0.9793
# 6      Random Forest   297.79  3.492538e+05    0.9781
